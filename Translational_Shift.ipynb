# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharmen123-creator/OpenCV/blob/master/Translational_Shift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
test = cv2.imread('taj.jpg', 1)
plt.imshow(image)
plt.show()

# %%
test = cv2.imread('taj.jpg', 1)
shift1 = np.float32([[1,0,0],[0,1,100]])
down = cv2.warpAffine(test, shift1, (test.shape[1], test.shape[0]))
plt.imshow(down)
plt.show()

# %%
test = cv2.imread('taj.jpg', 1)
shift1 = np.float32([[1,0,100],[0,1,0]])
right = cv2.warpAffine(test, shift1, (test.shape[1], test.shape[0]))
plt.imshow(right)
plt.show()

# %%
test = cv2.imread('taj.jpg', 1)
shift1 = np.float32([[100,0,1],[1,0,0]])
down = cv2.warpAffine(test, shift1, (test.shape[1], test.shape[0]))
plt.imshow(down)
plt.show()
